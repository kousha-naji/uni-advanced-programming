# %% [markdown]
# ![IMG_20250808_025949_411.jpg](attachment:IMG_20250808_025949_411.jpg)

# %% [markdown]
# ## Base Case

# %%
# Out:
# 24

# %% [markdown]
# ## Recursive Case

# %%
def rec_recursive_factorial(n):
